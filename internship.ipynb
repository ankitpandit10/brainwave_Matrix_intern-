# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('sales_06_FY2020-21 copy.csv')
data.info()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6224\1223585852.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('sales_06_FY2020-21 copy.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286392 entries, 0 to 286391
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          286392 non-null  object
#  1   order_date        286392 non-null  object
#  2   status            286392 non-null  object
#  3   item_id           286392 non-null  float64
#  4   sku               286392 non-null  object
#  5   qty_ordered       286392 non-null  float64
#  6   price             286392 non-null  float64
#  7   value             286392 non-null  float64
#  8   discount_amount   286392 non-null  float64
#  9   total             286392 non-null  float64
#  10  category          286392 non-null  object
# ...

# %%
data.head()
# Out:
#     order_id  order_date    status   item_id                  sku  \
# 0  100354678  2020-10-01  received  574772.0   oasis_Oasis-064-36
# 1  100354678  2020-10-01  received  574774.0      Fantastic_FT-48
# 2  100354680  2020-10-01  complete  574777.0      mdeal_DMC-610-8
# 3  100354680  2020-10-01  complete  574779.0   oasis_Oasis-061-36
# 4  100367357  2020-11-13  received  595185.0  MEFNAR59C38B6CA08CD
#
#    qty_ordered  price   value  discount_amount   total  ...          SSN  \
# 0         21.0   89.9  1798.0              0.0  1798.0  ...  627-31-5251
# 1         11.0   19.0   190.0              0.0   190.0  ...  627-31-5251
# 2          9.0  149.9  1199.2              0.0  1199.2  ...  627-31-5251
# 3          9.0   79.9   639.2              0.0   639.2  ...  627-31-5251
# 4          2.0   99.9    99.9              0.0    99.9  ...  627-31-5251
#
#      Phone No.  Place Name  County    City State    Zip Region User Name  \
# ...

# %%
import pandas as pd
df=pd.read_csv('sales_06_FY2020-21 copy.csv')
newddf=df.dropna()
data.info()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6224\1479499948.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('sales_06_FY2020-21 copy.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286392 entries, 0 to 286391
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          286392 non-null  object
#  1   order_date        286392 non-null  object
#  2   status            286392 non-null  object
#  3   item_id           286392 non-null  float64
#  4   sku               286392 non-null  object
#  5   qty_ordered       286392 non-null  float64
#  6   price             286392 non-null  float64
#  7   value             286392 non-null  float64
#  8   discount_amount   286392 non-null  float64
#  9   total             286392 non-null  float64
#  10  category          286392 non-null  object
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

 
 
# reading the database
data = pd.read_csv("sales_06_FY2020-21 copy.csv")
 
# Scatter plot with day against tip
plt.hist(data['item_id'], data['price'])
 
# Adding Title to the Plot
plt.title("histogram")
 
# Setting the X and Y labels
plt.xlabel('item_id')
plt.ylabel('price')
 
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6224\3387953187.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("sales_06_FY2020-21 copy.csv")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 10
#       7 data = pd.read_csv("sales_06_FY2020-21 copy.csv")
#       9 # Scatter plot with day against tip
# ---> 10 plt.hist(data['item_id'], data['price'])
#      12 # Adding Title to the Plot
#      13 plt.title("histogram")
#
# File c:\Users\lenovo\miniconda3\lib\site-packages\matplotlib\pyplot.py:2581, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2575 @_copy_docstring_and_deprecators(Axes.hist)
#    2576 def hist(
# ...

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("sales_06_FY2020-21 copy.csv")

# Convert order_date to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# --- 1. Sales Performance ---
# Monthly Sales Trend
monthly_sales = df.groupby(df['order_date'].dt.to_period('M'))['total'].sum().reset_index()
monthly_sales['order_date'] = monthly_sales['order_date'].astype(str)
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, x='order_date', y='total')
plt.title('Monthly Sales Trend')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6224\81636178.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("sales_06_FY2020-21 copy.csv")

# %%
top_categories = df.groupby('category')['total'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
top_categories.plot(kind='bar')
plt.title('Top-Selling Categories')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Sales by Region
region_sales = df.groupby('Region')['total'].sum().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
region_sales.plot(kind='bar', color='skyblue')
plt.title('Sales by Region')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %%
# --- 2. Customer Segmentation ---
# Age Distribution
plt.figure(figsize=(10, 5))
sns.histplot(df['age'], bins=30, kde=True)
plt.title('Customer Age Distribution')
plt.show()

# %%
# Gender-wise Distribution
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Gender')
plt.title('Customer Gender Distribution')
plt.show()

# %%
# --- 3. Discount Impact ---
# Discount vs. Quantity Ordered
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Discount_Percent', y='qty_ordered', alpha=0.3)
plt.title('Discount Percent vs Quantity Ordered')
plt.show()

# %%
# Total Discount Given Over Time
df['discount_value'] = df['value'] * df['Discount_Percent'] / 100
monthly_discount = df.groupby(df['order_date'].dt.to_period('M'))['discount_value'].sum().reset_index()
monthly_discount['order_date'] = monthly_discount['order_date'].astype(str)
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_discount, x='order_date', y='discount_value')
plt.title('Monthly Discount Given')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- 4. Order & Product Insights ---
# Average Order Value
avg_order_value = df.groupby('order_id')['total'].sum().mean()
print(f"Average Order Value: ${avg_order_value:.2f}")
# Out:
# Average Order Value: $1158.31

# %%
# SKU-Level Performance
top_skus = df.groupby('sku')['total'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
top_skus.plot(kind='bar')
plt.title('Top Performing SKUs')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- 5. Payment Method Trends ---
payment_method_counts = df['payment_method'].value_counts()
plt.figure(figsize=(8, 5))
sns.barplot(x=payment_method_counts.index, y=payment_method_counts.values)
plt.title('Payment Method Distribution')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- 6. Customer Retention & Loyalty ---
df['Customer Since'] = pd.to_datetime(df['Customer Since'])
df['customer_lifetime_days'] = (df['order_date'] - df['Customer Since']).dt.days
plt.figure(figsize=(10, 6))
sns.histplot(df['customer_lifetime_days'], bins=30, kde=True)
plt.title('Customer Lifetime (Days)')
plt.show()

# %%
# High-Value Customers
customer_spend = df.groupby('cust_id')['total'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
customer_spend.plot(kind='bar')
plt.title('Top 10 High-Value Customers')
plt.ylabel('Total Spend')
plt.tight_layout()
plt.show()
